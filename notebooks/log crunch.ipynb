# %% [markdown]
# # Funnelback crawls
# This notebook import links data into the Neo4j DB.

# %%
from py2neo import neo4j, rel

# %%
try:
    db = neo4j.GraphDatabaseService('http://vly.unimelb.edu.au:7474/db/data')
    db_subdomains = db.get_or_create_index(neo4j.Node, "Subdomains")
    db_pagelist = db.get_or_create_index(neo4j.Node, "Pages")
    db_pages = db.get_or_create_index(neo4j.Relationship, "Pageowners")
    db_links = db.get_or_create_index(neo4j.Relationship, "Links")
    
except:
    print('Failed to connect')
    

report_date = '2013-05-17'

# %% [markdown]
# ### Helper functions

# %%
class Cruncher():
    def __init__(self):
        self.temp_subdomain = ''
        self.temp_rships = {}
        self.index_limit = 10
        self.batch_limit = 20
        self.write_batch_counter = 0
        self.read_batch = neo4j.ReadBatch(db)
        self.write_batch = neo4j.WriteBatch(db)
        
    def check_ambiguity(self, results):
        '''
        Check for multiple returning results
        '''
        if len(results) > 1:
            print("Ambiguous search results, check for duplicates")
            return results
        if not results:
            return
        return results[0]
    
    def create_subdomain_node(self, hostname):
        temp = db.create({"hostname" : hostname})
        db_subdomains.get_or_create('contains', self.temp_subdomain['hostname'] + page, (self.temp_subdomain, "contains", temp))
        return temp
    
    def get_subdomain_node(self, hostname, search_type='fuzzy'):
        '''
        Searches for hostname and checks if multiple results are returned
        '''
        if self.temp_subdomain and self.temp_subdomain['hostname'] == hostname:
            return self.temp_subdomain
        if search_type == 'exact':
            query = 'hostname:' + hostname + '*'
        else:
            query = 'hostname:*' + hostname + '*'
            
        if hostname == 'unimelb.edu.au':
            query = 'hostname:' + hostname
        else:
            query = query.split('unimelb.edu.au')[0] + '*'
        results = [x for x in db_subdomains.query(query)]
        if not results:
            return
        else:
            if len(results) > 1 and search_type != 'exact':
                return self.get_subdomain_node(hostname, 'exact')
        return self.check_ambiguity(results)
    
    def get_subdomain_page_node(self, hostname, page):
        '''
        Return connecting page node for a matching URI relationship
        '''
        temp = self.get_subdomain_node(hostname)
        if not temp:
            print('No results returned')
            return
        self.temp_subdomain = temp
        if not len(self.temp_rships) or hostname not in self.temp_rships:
            if len(self.temp_rships) == self.index_limit:
                self.temp_rships.popitem()
            self.temp_rships[hostname] = db.match(start_node=temp, rel_type='contains')
            
        results = self.check_ambiguity([z for z in self.temp_rships[hostname] if page == z['uri']])
        if not results:
            print("No page found")
            new_node = self.create_subdomain_page_node(page)
            return new_node
        if type(results) == list:
            return results[0].end_node
        return results.end_node
    
    def get_subdomain_link(self, url):
        protocol = ''
        hostname = ''
        page = ''
        temp = url
        if 'http' in url:
            (protocol,temp) = url.split('//')[0]
        (hostname, page) = temp.split('/',1)
        page = '/' + page
        print(hostname, page)
        if 'unimelb.edu.au' not in hostname:
            print('Non-unimelb link:',hostname, page)
            return
        return self.get_subdomain_page_node(hostname, page)
    
    def create_subdomain_page_node(self, page):
        temp = db_pagelist.get_or_create("url", page, {'url': page, 'added': report_date})
        # self.batch_write_add(self.temp_subdomain, temp, "contains")
        db_pages.get_or_create('contains', self.temp_subdomain['hostname'] + page, (self.temp_subdomain, "contains", temp))
        return temp
        
    def batch_write_add(self, start_node, end_node, relation="LINKS_TO"):
        self.write_batch.create(rel(start_node, relation, end_node))
        self.write_batch_counter += 1
        if self.write_batch_counter == 10:
            self.write_batch_flush()
            
    def write_batch_flush(self):
        out = self.write_batch.submit()
        self.write_batch_counter = 0
        for each in out:
            db_links.add("links", "local", each)

# %% [markdown]
# #### Process data

# %%
i=0
index_limit = 10
data = {}
k = 1

with open("index.anchors", 'r') as f:
    while k:
        try:
            k = f.readline()
            i += 1
            if k:
                if k[0] == '+':
                    point_domain = k[1:].split('/')[0]
                    point_page = '/' + k[1:-1].split('/', 1)[1]
                    if 'www.' in point_domain:
                        point_domain = point_domain[4:]
                    if point_domain not in data:
                        data[point_domain] = {}
                    if point_page not in data[point_domain]:
                        data[point_domain][point_page] = []
                else:
                    blob = k.split(' --- ')
                    if len(blob) > 1:
                        if 'www.' in blob[0]:
                            blob[0] = blob[0][4:]
                        if ']' in blob[1]:
                            blob[1] = blob[1].split(']')[1][:-1]
                        if 'thumb' in blob[1] or 'images' in blob[1][:6]:
                            blob[1] = ''    
                        data[point_domain][point_page].append(blob)
        except UnicodeDecodeError:
            pass

# %%
blin = Cruncher()

for a in data:
    for b in data[a]:
        working_node = blin.get_subdomain_page_node(a, b)
        for each in data[a][b]:
            blin.batch_write_add(working_node, blin.get_subdomain_link(each[0]))
blin.write_batch_flush()
# Out:
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# No page found
# ...
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# No page found
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# No page found
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# Ambiguous search results, check for duplicates
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-235-758da2c6ec00> in <module>()
#       3 for a in data:
#       4     for b in data[a]:
# ----> 5         working_node = blin.get_subdomain_page_node(a, b)
#       6         for each in data[a][b]:
#       7             blin.batch_write_add(working_node, blin.get_subdomain_link(each[0]))
#
# <ipython-input-234-2196d3bd8f7e> in get_subdomain_page_node(self, hostname, page)
#      57             self.temp_rships[hostname] = db.match(start_node=temp, rel_type='contains')
#      58
# ---> 59         results = self.check_ambiguity([z for z in self.temp_rships[hostname] if page == z['uri']])
#      60         if not results:
#      61             print("No page found")
#
# <ipython-input-234-2196d3bd8f7e> in <listcomp>(.0)
#      57             self.temp_rships[hostname] = db.match(start_node=temp, rel_type='contains')
#      58
# ---> 59         results = self.check_ambiguity([z for z in self.temp_rships[hostname] if page == z['uri']])
#      60         if not results:
#      61             print("No page found")
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\neo4j.py in __getitem__(self, key)
#     792
#     793     def __getitem__(self, key):
# --> 794         return self.get_properties().get(key, None)
#     795
#     796     def __hash__(self):
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\neo4j.py in get_properties(self)
#     853         if self.__uri__:
#     854             uri = self.__metadata__['properties']
# --> 855             rs = self._send(rest.Request(self._graph_db, "GET", uri))
#     856             self._properties = rs.body or {}
#     857         return self._properties
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\rest.py in _send(self, request)
#     426         """
#     427         try:
# --> 428             return self._client().send(request)
#     429         except socket.error as err:
#     430             raise SocketError(err)
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\rest.py in send(self, request, *args, **kwargs)
#     350
#     351     def send(self, request, *args, **kwargs):
# --> 352         rs = self._send_request(request.method, request.uri, request.body, request.headers)
#     353         if rs.status in _auto_redirects:
#     354             # automatic redirection - discard data and call recursively
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\rest.py in _send_request(self, method, uri, data, headers)
#     339                 http.request(method, path, data, _headers)
#     340                 logger.debug("Awaiting response")
# --> 341                 rs = http.getresponse()
#     342                 logger.info("{0} {1} {2}".format(rs.status, rs.reason, dict(rs.getheaders())))
#     343                 return rs
#
# C:\Python33\lib\http\client.py in getresponse(self)
#    1129             response = self.response_class(self.sock, method=self._method)
#    1130
# -> 1131         response.begin()
#    1132         assert response.will_close != _UNKNOWN
#    1133         self.__state = _CS_IDLE
#
# C:\Python33\lib\http\client.py in begin(self)
#     352         # read until we get a non-100 response
#     353         while True:
# --> 354             version, status, reason = self._read_status()
#     355             if status != CONTINUE:
#     356                 break
#
# C:\Python33\lib\http\client.py in _read_status(self)
#     314
#     315     def _read_status(self):
# --> 316         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     317         if len(line) > _MAXLINE:
#     318             raise LineTooLong("status line")
#
# C:\Python33\lib\socket.py in readinto(self, b)
#     295         while True:
#     296             try:
# --> 297                 return self._sock.recv_into(b)
#     298             except timeout:
#     299                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Tests

# %%
# search for invalid URL
blin = Cruncher()
blin.get_subdomain_page_node('alumni.unimelb.edu.au', 'askdfsadf')
# Out:
# Request failed (CannotSendRequest), retrying
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-170-c0143587d79d> in <module>()
#       1 # search for invalid URL
#       2 blin = Cruncher()
# ----> 3 blin.get_subdomain_page_node('alumni.unimelb.edu.au', 'askdfsadf')
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_page_node(self, hostname, page)
#      46         Return connecting page node for a matching URI relationship
#      47         '''
# ---> 48         temp = self.get_subdomain_node(hostname)
#      49         if not temp:
#      50             print('No results returned')
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ...
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      39         else:
#      40             if len(results) > 1:
# ---> 41                 return self.get_subdomain_node(hostname, 'exact')
#      42         return self.check_ambiguity(results)
#      43
#
# <ipython-input-166-a6a6222e6e1f> in get_subdomain_node(self, hostname, search_type)
#      34         else:
#      35             query = query.split('unimelb.edu.au')[0] + '*'
# ---> 36         results = db_subdomains.query(query)
#      37         if not results:
#      38             return
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\neo4j.py in query(self, query)
#    2042             self._content_type(item['self'])
#    2043             for item in self._send(rest.Request(self._graph_db, "GET", "{0}?query={1}".format(
# -> 2044                 self.__uri__, quote(query, "")
#    2045             ))).body
#    2046         ]
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\neo4j.py in <listcomp>(.0)
#    2041         return [
#    2042             self._content_type(item['self'])
# -> 2043             for item in self._send(rest.Request(self._graph_db, "GET", "{0}?query={1}".format(
#    2044                 self.__uri__, quote(query, "")
#    2045             ))).body
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\neo4j.py in __init__(self, uri)
#     950
#     951     def __init__(self, uri):
# --> 952         _Entity.__init__(self, uri)
#     953
#     954     def __eq__(self, other):
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\neo4j.py in __init__(self, uri)
#     781
#     782     def __init__(self, uri):
# --> 783         rest.Resource.__init__(self, uri)
#     784         self._labels = set()
#     785         self._properties = {}
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\rest.py in __init__(self, uri)
#     374
#     375     def __init__(self, uri):
# --> 376         self.__uri__ = uri
#     377         self.__metadata = PropertyCache()
#     378
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\rest.py in __uri__(self, uri)
#     403             self.__uri = None
#     404         else:
# --> 405             self.__uri = URI(uri)
#     406
#     407     def _client(self):
#
# C:\Python33\lib\site-packages\py2neo-1.5-py3.3.egg\py2neo\rest.py in __init__(self, uri)
#     208         self.query = parsed.query
#     209         self.fragment = parsed.fragment
# --> 210         self.username = parsed.username
#     211         self.password = parsed.password
#     212         self.hostname = parsed.hostname
#
# C:\Python33\lib\urllib\parse.py in username(self)
#     134     @property
#     135     def username(self):
# --> 136         return self._userinfo[0]
#     137
#     138     @property
#
# C:\Python33\lib\urllib\parse.py in _userinfo(self)
#     165     @property
#     166     def _userinfo(self):
# --> 167         netloc = self.netloc
#     168         userinfo, have_info, hostinfo = netloc.rpartition('@')
#     169         if have_info:
#
# RuntimeError: maximum recursion depth exceeded while calling a Python object

# %%
for a in data:
    for b in data[a]:
        print(a,b)

# %%
# search for homepage
a = blin.get_subdomain_node('unimelb.edu.au')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-79d638819031> in <module>()
#       1 # search for homepage
# ----> 2 a = blin.get_subdomain_node('unimelb.edu.au')
#
# <ipython-input-12-71b753d3509c> in get_subdomain_node(self, hostname, search_type)
#      54         else:
#      55             z = results
# ---> 56             if len(results) > 1 and search_type != 'exact':
#      57                 return self.get_subdomain_node(hostname, 'exact')
#      58         return self.check_ambiguity(results)
#
# TypeError: object of type 'generator' has no len()

# %%
z = [z for z in blin.temp_rships['queens.unimelb.edu.au']][0]

# %%
db_subdomains.

# %%
z.create_relationship_to
# Out:
# Node('http://vly.unimelb.edu.au:7474/db/data/node/657168')

# %%
test = neo4j.WriteBatch(db)

# %%
test.add_indexed_node(
# Out:
# Request failed (CannotSendRequest), retrying

# %%
data
# Out:
# {'queens.unimelb.edu.au': {'/': []}}

# %%
z = 1

# %% [markdown]
# ### Cruncher v2

# %%
class Cruncher():
    def __init__(self):
        self.temp_subdomain = ''
        self.temp_rships = {}
        self.index_limit = 10
        self.batch_limit = 10
        self.write_batch_rels_counter = 0
        self.write_batch_nodes_counter = 0
        self.read_batch = neo4j.ReadBatch(db)
        self.write_batch_rels = neo4j.WriteBatch(db)
        self.write_batch_nodes = neo4j.WriteBatch(db)
        
    def check_ambiguity(self, results):
        '''
        Check for multiple returning results
        '''
        if len(results) > 1:
            print("Ambiguous search results, check for duplicates")
            return results
        if not results:
            return
        return results[0]
    
    def add_to_index(self, index, node, ikey):
        self.write_batch_rels.add_to_index(neo4j.Node, index, "hostname", ikey, node)
        self.write_batch_nodes_counter += 1
        if self.write_batch_nodes_counter == self.batch_limit:
            self.write_batch_nodes_counter.submit()
            self.write_batch_nodes_counter = 0
    
    def create_subdomain_node(self, hostname):
        temp = db.create({"hostname" : hostname})
        self.add_to_index(db_subdomains, temp[0], hostname)
        return temp[0]
    
    def get_subdomain_node(self, hostname, search_type='fuzzy'):
        '''
        Searches for hostname and checks if multiple results are returned
        '''
        if self.temp_subdomain and self.temp_subdomain['hostname'] == hostname:
            return self.temp_subdomain
        if search_type == 'exact':
            query = 'hostname:' + hostname + '*'
        else:
            query = 'hostname:*' + hostname + '*'
            
        if hostname == 'unimelb.edu.au':
            query = 'hostname:' + hostname
        else:
            query = query.split('unimelb.edu.au')[0] + '*'
        results = [x for x in db_subdomains.query(query)]
        if not results:
            return self.create_subdomain_node(hostname)
        else:
            if len(results) > 1 and search_type != 'exact':
                return self.get_subdomain_node(hostname, 'exact')
        return self.check_ambiguity(results)
    
    def get_subdomain_page_node(self, hostname, page):
        '''
        Return connecting page node for a matching URI relationship
        '''
        temp = self.get_subdomain_node(hostname)
        if not temp:
            print('No results returned')
            return
        self.temp_subdomain = temp
        if not len(self.temp_rships) or hostname not in self.temp_rships:
            if len(self.temp_rships) == self.index_limit:
                self.temp_rships.popitem()
            self.temp_rships[hostname] = db.match(start_node=temp, rel_type='CONTAINS')
            
        results = self.check_ambiguity([z for z in self.temp_rships[hostname] if page == z['uri']])
        if not results:
            print("No page found")
            new_node = self.create_subdomain_page_node(page)
            return new_node
        if type(results) == list:
            return results[0].end_node
        return results.end_node
    
    def get_subdomain_link(self, url):
        protocol = ''
        hostname = ''
        page = ''
        temp = url
        if 'http' in url:
            (protocol,temp) = url.split('//')[0]
        (hostname, page) = temp.split('/',1)
        page = '/' + page
        print(hostname, page)
        if 'unimelb.edu.au' not in hostname:
            print('Non-unimelb link:',hostname, page)
            return
        return self.get_subdomain_page_node(hostname, page)
    
    def create_subdomain_page_node(self, page):
        temp = db_pagelist.get_or_create("url", page, {'url': page, 'added': report_date})
        #self.batch_write_add(self.temp_subdomain, temp, "contains")
        db_pages.get_or_create('CONTAINS', self.temp_subdomain['hostname'] + page, (self.temp_subdomain, "contains", temp))
        return temp
        
    def batch_write_add(self, start_node, end_node, relation="LINKS_TO", page="general"):
        self.write_batch_rels.create_in_index(neo4j.Relationship, db_links, "link", page, rel(start_node, relation, end_node)))
        self.write_batch_rels_counter += 1
        if self.write_batch_rels_counter == 10:
            self.write_batch_flush()
            
    def write_batch_flush(self):
        out = self.write_batch_rels.submit()
        self.write_batch_rels_counter = 0

# %%
blin = Cruncher()

for a in data:
    print("Entering", a)
    for b in data[a]:
        working_node = blin.get_subdomain_page_node(a, b)
        print(data[a])
        for each in data[a][b]:
            page_node = blin.get_subdomain_link(each[0])
            print(type(working_node), type(page_node))
            blin.batch_write_add(working_node, page_node, "LINKS_TO", page_node['url'])
blin.write_batch_flush()

# %%
data['unimelb.edu.au']
# Out:
# {'/': [],
#  '/150/': [],
#  '/150/index.html': [],
#  '/2011-qs-rankings-healthsci.html': [],
#  '/Council/': [],
#  '/Council/ac/': [],
#  '/Council/bec/': [],
#  '/Council/cngc/': [],
#  '/Council/elections/': [],
#  '/Council/elections/pdf/result-acad.pdf': [],
#  '/Council/elections/pdf/result.pdf': [],
#  '/Council/finance/': [],
#  '/Council/honours/': [],
#  '/Council/honours/pdf/hd-procedures.pdf': [],
#  '/Council/honours/pdf/mlp-guidelines.pdf': [],
#  '/Council/ltc/': [],
#  '/Council/ltc/pdf/trmmm.pdf': [],
#  '/Council/minutes/apr93.html': [],
#  '/Council/minutes/apr94.html': [],
#  '/Council/minutes/apr95.html': [],
#  '/Council/minutes/apr96.html': [],
#  '/Council/minutes/apr97.html': [],
#  '/Council/minutes/apr98.html': [],
#  '/Council/minutes/apr99.html': [],
#  '/Council/minutes/aug92.html': [],
#  '/Council/minutes/aug93.html': [],
#  '/Council/minutes/dec00.html': [],
#  '/Council/minutes/dec92.html': [],
#  '/Council/minutes/dec93.html': [],
#  '/Members/mcd.html': [],
#  '/Members/mcgaw.html': [],
#  '/Members/mckew.html': [],
#  '/Members/museum.html': [],
#  '/Members/nobellaureateprofessor.html': [],
#  '/Members/opto.html': [],
#  '/Members/postcolonial.html': [],
#  '/Members/professor.html': [],
#  '/Members/provost.html': [],
#  '/Members/readers.html': [],
#  '/Members/seniorstaff.html': [],
#  '/Members/stanley.html': [],
#  '/Members/tasman.html': [],
#  '/Members/vc-fellows.html': [],
#  '/Members/vcafac.html': [],
#  '/Members/vcamfac.html': [],
#  '/Members/vetscifac.html': [],
#  '/Members/vpadmin.html': [],
#  '/Members/vpbuilding.html': [],
#  '/Members/vpcommercialisation.html': [],
#  '/Members/vpcorposerv.html': [],
#  '/Members/vphr.html': [],
#  '/Members/vpresearch.html': [],
#  '/Members/walter.html': [],
#  '/Members/zoolo.html': [],
#  '/Statutes/': [],
#  '/Statutes/contents.html': [],
#  '/Statutes/decupdates.html': [],
#  '/Statutes/octupdates.html': [],
#  '/Statutes/pdf/Intellectual_Property_Principles_under_review.pdf': [],
#  '/Statutes/pdf/centres.pdf': [],
#  '/Statutes/pdf/centrestrain.pdf': [],
#  '/Statutes/pdf/r101r1.pdf': [],
#  '/Statutes/pdf/r103r1.pdf': [],
#  '/Statutes/pdf/r111a1.pdf': [],
#  '/Statutes/pdf/r111a2.pdf': [],
#  '/Statutes/pdf/r111a3.pdf': [],
#  '/Statutes/pdf/r111r1.pdf': [],
#  '/Statutes/pdf/r111r3sgs.pdf': [],
#  '/Statutes/pdf/r115r2.pdf': [],
#  '/Statutes/pdf/r151r1.pdf': [],
#  '/Statutes/pdf/r151r2.pdf': [],
#  '/Statutes/pdf/r151r3.pdf': [],
#  '/Statutes/pdf/r171r8.pdf': [],
#  '/Statutes/pdf/r21r1.pdf': [],
#  '/Statutes/pdf/r25r2.pdf': [],
#  '/Statutes/pdf/r25r4.pdf': [],
#  '/Statutes/pdf/r25r5.pdf': [],
#  '/Statutes/pdf/r25r6.pdf': [],
#  '/Statutes/pdf/r31r1.pdf': [],
#  '/Statutes/pdf/r41r1.pdf': [],
#  '/Statutes/pdf/r51r1.pdf': [],
#  '/Statutes/pdf/r51r2.pdf': [],
#  '/Statutes/pdf/r51r3.pdf': [],
#  '/Statutes/pdf/r51r4.pdf': [],
#  '/Statutes/pdf/r51r5.pdf': [],
#  '/Statutes/pdf/r51r7.pdf': [],
#  '/Statutes/pdf/r81r1.pdf': [],
#  '/Statutes/pdf/r81r2.pdf': [],
#  '/Statutes/pdf/r81r3.pdf': [],
#  '/Statutes/pdf/r81r4.pdf': [],
#  '/Statutes/pdf/r81r5.pdf': [],
#  '/Statutes/pdf/r81r7.pdf': [],
#  '/Statutes/pdf/r81r8.pdf': [],
#  '/Statutes/pdf/r83r1.pdf': [],
#  '/Statutes/pdf/r83r2.pdf': [],
#  '/Statutes/pdf/r83r3.pdf': [],
#  '/Statutes/pdf/r83r4.pdf': [],
#  '/Statutes/pdf/r83r5.pdf': [],
#  '/Statutes/pdf/r960r1.pdf': [],
#  '/Statutes/pdf/r961r1.pdf': [],
